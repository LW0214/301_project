# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.datasets import imdb
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from gensim.models.keyedvectors import KeyedVectors
from keras.layers import Dense, Input, GlobalMaxPooling1D
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.models import Model
from keras.layers import Input, Dense, Embedding, Conv2D, MaxPooling2D, Dropout,concatenate
from keras.layers.core import Reshape, Flatten
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras.models import Model
from keras import regularizers
from keras.layers import Embedding
import pickle as pkl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/new_project
# Out:
# /content/drive/MyDrive/Colab Notebooks/new_project

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("imdb.csv", usecols=["review", "sentiment"], encoding='latin-1')
## 1 - positive, 0 - negative
df.sentiment = (df.sentiment == "positive").astype("int")
df.head()
# Out:
#                                               review  sentiment
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1

# %% [markdown]
# ## split

# %%
val_size = int(df.shape[0] * 0.15)
test_size = int(df.shape[0] * 0.15)


def train_val_test_split(df=None, train_percent=0.7, test_percent=0.15, val_percent=0.15):
  df = df.sample(frac=1)
  train_df = df[: int(len(df)*train_percent)]
  test_df = df[int(len(df)*train_percent)+1 : int(len(df)*(train_percent+test_percent))]
  val_df = df[int(len(df)*(train_percent + test_percent))+1 : ]
  return train_df, test_df, val_df

train_df, test_df, val_df = train_val_test_split(df, 0.7, 0.15, 0.15)
train_labels, train_texts = train_df.values[:,1], train_df.values[:,0]
val_labels, val_texts = val_df.values[:,1], val_df.values[:,0]
test_labels, test_texts = test_df.values[:,1], test_df.values[:,0]
print(len(train_df), len(test_df), len(val_df))
print(len(train_texts), len(train_labels), len(val_df))
# Out:
# 35000 7499 7499
# 35000 35000 7499

# %%
train_texts[0]
# Out:
# 'I raced to the library to check out this miniseries after having just finished listening to the marvelous "talking books" unabridged version of the book. The first half of this TV version is really very good, but it stumbles quite a bit in the second half. The relationship with the trustee is overplayed and conflicts are inserted between Jean and Joe that don\'t exist in Shute\'s story, unwisely in my opinion, as they greatly diminish the power of their love story. I was disappointed to find that the wonderful Bryan Brown\'s Joe seemed a lot cockier and much less appealing than the man in the book, but Helen Morse\'s Jean was really quite good. I think they would have had to make this a 10-hour miniseries to develop the outback story properly. But all that said, I did watch whole thing in more or less one go and did appreciate its merits, all the while wishing that someone would do a less soapy remake.'

# %%
train_labels
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=object)

# %% [markdown]
# ## Tokenize text of the training data with keras text preprocessing functions

# %%
#english

from spacy.tokenizer import Tokenizer
from spacy.lang.en import English

def process_tokens(text):
    """
    function to process tokens, replace any unwanted chars
    """
    preprocessed_text = text.lower().replace(",", "").replace(".", "").replace(":", "").replace(")", "").replace("-", "").replace("(", "")
    preprocessed_text = ''.join([i for i in preprocessed_text if not preprocessed_text.isdigit()])
    return preprocessed_text

def preprocessing(data):
    """
    preprocessing data to list of tokens
    """
    nlp = English()
    tokenizer = Tokenizer(nlp.vocab)
    preprocessed_data = []
    for sentence in data:
        sentence = process_tokens(sentence)
        tokens = tokenizer(sentence)
        tlist = []
        for token in tokens:
            tlist.append(str(token))
        preprocessed_data.append(tlist)
    return preprocessed_data

train_data = preprocessing(train_texts)
val_data = preprocessing(val_texts)
test_data = preprocessing(test_texts)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
NUM_WORDS=20000
tokenizer = Tokenizer(num_words=NUM_WORDS,filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n\'',
                      lower=True)

# %%
tokenizer.fit_on_texts(train_data)
sequences_train = tokenizer.texts_to_sequences(train_data)
sequences_valid=tokenizer.texts_to_sequences(val_data)
sequences_test=tokenizer.texts_to_sequences(test_data)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 208044 unique tokens.

# %%
len(sequences_train)
# Out:
# 35000

# %%
len(word_index)
# Out:
# 208044

# %%
#decode y

y_train = np.array(train_labels)
y_val = np.array(val_labels)
y_test = np.array(test_labels)

y_train = y_train.astype('int')
y_val = y_val.astype('int')
y_test = y_test.astype('int')

from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
y_val = to_categorical(y_val, 2)

# %%
print(f'X_train.shape: {len(sequences_train)}, y_train.shape: {y_train.shape}')
# Out:
# X_train.shape: 35000, y_train.shape: (35000, 2)

# %% [markdown]
# ### pad sequence

# %%
X_train = pad_sequences(sequences_train)
X_val = pad_sequences(sequences_valid,maxlen=X_train.shape[1])
X_test=pad_sequences(sequences_test,maxlen=X_train.shape[1])

# %%
print('Shape of X train and X validation tensor:', X_train.shape,X_val.shape)
print('Shape of label train and validation tensor:', y_train.shape,y_val.shape)
# Out:
# Shape of X train and X validation tensor: (35000, 2251) (7499, 2251)
# Shape of label train and validation tensor: (35000, 2) (7499, 2)

# %%
X_train.shape[1]
# Out:
# 2251

# %%
X_train[0]
# Out:
# array([  0,   0,   0, ..., 219,  42, 430], dtype=int32)

# %% [markdown]
# ## use word2vec as embedding layer

# %%
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess

from gensim.models.keyedvectors import KeyedVectors


EMBEDDING_DIM=300
vocabulary_size=min(len(word_index)+1,NUM_WORDS)

# %%
vocabulary_size
# Out:
# 20000

# %%
#don't run
word_vectors = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)

embedding_matrix = np.zeros((vocabulary_size, EMBEDDING_DIM))
for word, i in word_index.items():
    if i>=NUM_WORDS:
        continue
    try:
        embedding_vector = word_vectors[word]
        embedding_matrix[i] = embedding_vector
    except KeyError:
        print(f'word {word} not in w2v')
        embedding_matrix[i]=np.random.normal(0,np.sqrt(0.25),EMBEDDING_DIM)

del(word_vectors)
# Out:
# word and not in w2v
# word a not in w2v
# word of not in w2v
# word to not in w2v
# word /><br not in w2v
# word   not in w2v
# word />the not in w2v
# word <br not in w2v
# word i'm not in w2v
# word />i not in w2v
# word i've not in w2v
# word "the not in w2v
# word />this not in w2v
# word 10 not in w2v
# word â not in w2v
# word i'd not in w2v
# word />in not in w2v
# word />it not in w2v
# word film's not in w2v
# word />if not in w2v
# word it<br not in w2v
# word />but not in w2v
# word />there not in w2v
# word i'll not in w2v
# word movie<br not in w2v
# word film<br not in w2v
# word />and not in w2v
# word ! not in w2v
# word />a not in w2v
# word />as not in w2v
# word />it's not in w2v
# word 20 not in w2v
# word 'the not in w2v
# word />so not in w2v
# word />what not in w2v
# word it! not in w2v
# word "i not in w2v
# word   not in w2v
# word humour not in w2v
# word 80's not in w2v
# word 15 not in w2v
# word 30 not in w2v
# word />all not in w2v
# word />my not in w2v
# word movie's not in w2v
# word />one not in w2v
# word " not in w2v
# word ? not in w2v
# word "a not in w2v
# word />overall not in w2v
# word movie! not in w2v
# word time<br not in w2v
# word clichã© not in w2v
# word />for not in w2v
# word it? not in w2v
# word clichã©s not in w2v
# word favourite not in w2v
# word theatre not in w2v
# word 100 not in w2v
# word />to not in w2v
# word />now not in w2v
# word character's not in w2v
# word lowbudget not in w2v
# word 90 not in w2v
# word them<br not in w2v
# word />i'm not in w2v
# word />when not in w2v
# word 70's not in w2v
# word director's not in w2v
# word />however not in w2v
# word />while not in w2v
# word />you not in w2v
# word 12 not in w2v
# word 80s not in w2v
# word movie? not in w2v
# word him<br not in w2v
# word this<br not in w2v
# word 40 not in w2v
# word all<br not in w2v
# word / not in w2v
# word hitchcock not in w2v
# word 50 not in w2v
# word me<br not in w2v
# word one<br not in w2v
# word />then not in w2v
# word />some not in w2v
# word />not not in w2v
# word well<br not in w2v
# word "what not in w2v
# word 70s not in w2v
# word />well not in w2v
# word keaton not in w2v
# word />also not in w2v
# word that<br not in w2v
# word man" not in w2v
# word 10/10 not in w2v
# word />on not in w2v
# word story<br not in w2v
# word />after not in w2v
# word />at not in w2v
# word film! not in w2v
# word overthetop not in w2v
# word and/or not in w2v
# word why? not in w2v
# word clichã©d not in w2v
# word bmovie not in w2v
# word />we not in w2v
# word />that not in w2v
# word />don't not in w2v
# word />first not in w2v
# word />anyway not in w2v
# word seagal not in w2v
# word />with not in w2v
# word />even not in w2v
# word "you not in w2v
# word way<br not in w2v
# word 11 not in w2v
# word />another not in w2v
# word movie" not in w2v
# word is<br not in w2v
# word 25 not in w2v
# word />of not in w2v
# word end<br not in w2v
# word this? not in w2v
# word tarzan not in w2v
# word 13 not in w2v
# word father's not in w2v
# word film? not in w2v
# word here<br not in w2v
# word that? not in w2v
# word good<br not in w2v
# word />although not in w2v
# word wwii not in w2v
# word out<br not in w2v
# word what? not in w2v
# word eastwood not in w2v
# word on<br not in w2v
# word right? not in w2v
# word 8/10 not in w2v
# word />there's not in w2v
# word 2001 not in w2v
# word life<br not in w2v
# word 60's not in w2v
# word />no not in w2v
# word />1 not in w2v
# word again<br not in w2v
# word 2005 not in w2v
# word mst3k not in w2v
# word />2 not in w2v
# word 7/10 not in w2v
# word writer/director not in w2v
# word bad<br not in w2v
# word pacino not in w2v
# word 14 not in w2v
# word it" not in w2v
# word sinatra not in w2v
# word stanwyck not in w2v
# word 45 not in w2v
# word "this not in w2v
# word columbo not in w2v
# word 1970s not in w2v
# word 90's not in w2v
# word 4/10 not in w2v
# word />3 not in w2v
# word connery not in w2v
# word "oh not in w2v
# word />oh not in w2v
# word better<br not in w2v
# word 2006 not in w2v
# word movies<br not in w2v
# word 1950s not in w2v
# word />by not in w2v
# word />from not in w2v
# word />unfortunately not in w2v
# word 20th not in w2v
# word />i've not in w2v
# word me" not in w2v
# word too<br not in w2v
# word tarantino not in w2v
# word 9/10 not in w2v
# word "it's not in w2v
# word 18 not in w2v
# word flynn not in w2v
# word "my not in w2v
# word "i'm not in w2v
# word 1980s not in w2v
# word realise not in w2v
# word colour not in w2v
# word fonda not in w2v
# word film; not in w2v
# word there<br not in w2v
# word 2000 not in w2v
# word films<br not in w2v
# word show's not in w2v
# word her<br not in w2v
# word work<br not in w2v
# word "in not in w2v
# word />finally not in w2v
# word 60s not in w2v
# word carrey not in w2v
# word 80 not in w2v
# word fulci not in w2v
# word walken not in w2v
# word matthau not in w2v
# word 17 not in w2v
# word girl's not in w2v
# word lugosi not in w2v
# word />yes not in w2v
# word bergman not in w2v
# word world<br not in w2v
# word />they not in w2v
# word funny<br not in w2v
# word />why not in w2v
# word 2004 not in w2v
# word 50's not in w2v
# word welles not in w2v
# word />despite not in w2v
# word 1/10 not in w2v
# word characters' not in w2v
# word life" not in w2v
# word watch<br not in w2v
# word grey not in w2v
# word 1950's not in w2v
# word characters<br not in w2v
# word 24 not in w2v
# word scene<br not in w2v
# word 16 not in w2v
# word     not in w2v
# word 3/10 not in w2v
# word />just not in w2v
# word one! not in w2v
# word />an not in w2v
# word up<br not in w2v
# word show<br not in w2v
# word you<br not in w2v
# word />he not in w2v
# word in<br not in w2v
# word ; not in w2v
# word    not in w2v
# word mustsee not in w2v
# word />4 not in w2v
# word 1/2 not in w2v
# word 100% not in w2v
# word seen<br not in w2v
# word />how not in w2v
# word not<br not in w2v
# word kubrick not in w2v
# word time! not in w2v
# word />like not in w2v
# word hollywood's not in w2v
# word story" not in w2v
# word />watch not in w2v
# word screen<br not in w2v
# word />maybe not in w2v
# word dead" not in w2v
# word etc<br not in w2v
# word more<br not in w2v
# word him? not in w2v
# word 2003 not in w2v
# word 60 not in w2v
# word 1999 not in w2v
# word />* not in w2v
# word streep not in w2v
# word />director not in w2v
# word behaviour not in w2v
# word "it not in w2v
# word "how not in w2v
# word was<br not in w2v
# word carradine not in w2v
# word brando not in w2v
# word times<br not in w2v
# word scenes<br not in w2v
# word onedimensional not in w2v
# word damme not in w2v
# word wife's not in w2v
# word 2002 not in w2v
# word be<br not in w2v
# word />"the not in w2v
# word "if not in w2v
# word much<br not in w2v
# word 1980 not in w2v
# word bronson not in w2v
# word sandler not in w2v
# word cagney not in w2v
# word movie; not in w2v
# word â not in w2v
# word plot<br not in w2v
# word great! not in w2v
# word "no not in w2v
# word good! not in w2v
# word madefortv not in w2v
# word 19th not in w2v
# word />other not in w2v
# word />most not in w2v
# word someone's not in w2v
# word "don't not in w2v
# word niro not in w2v
# word />still not in w2v
# word pg13 not in w2v
# word 35 not in w2v
# word hitchcock's not in w2v
# word garfield not in w2v
# word this! not in w2v
# word 1972 not in w2v
# word god's not in w2v
# word people<br not in w2v
# word "we not in w2v
# word cusack not in w2v
# word spielberg not in w2v
# word you! not in w2v
# word "good not in w2v
# word lemmon not in w2v
# word family's not in w2v
# word altman not in w2v
# word 1930s not in w2v
# word karloff not in w2v
# word troma not in w2v
# word "all not in w2v
# word either<br not in w2v
# word />ps not in w2v
# word with<br not in w2v
# word too! not in w2v
# word america's not in w2v
# word branagh not in w2v
# word />do not in w2v
# word that! not in w2v
# word you" not in w2v
# word streisand not in w2v
# word uwe not in w2v
# word you? not in w2v
# word 1970's not in w2v
# word sarandon not in w2v
# word custer not in w2v
# word />avoid not in w2v
# word griffith not in w2v
# word "star not in w2v
# word 2007 not in w2v
# word "bad not in w2v
# word 1973 not in w2v
# word love" not in w2v
# word />perhaps not in w2v
# word "film" not in w2v
# word austen not in w2v
# word 1960s not in w2v
# word 2/10 not in w2v
# word 1979 not in w2v
# word 50s not in w2v
# word "hey not in w2v
# word "so not in w2v
# word friend's not in w2v
# word meryl not in w2v
# word 1995 not in w2v
# word "american not in w2v
# word />its not in w2v
# word voight not in w2v
# word it; not in w2v
# word 2" not in w2v
# word character<br not in w2v
# word 1971 not in w2v
# word on! not in w2v
# word actor's not in w2v
# word other's not in w2v
# word king's not in w2v
# word years<br not in w2v
# word off<br not in w2v
# word 1993 not in w2v
# word series<br not in w2v
# word 1996 not in w2v
# word "why not in w2v
# word 1997 not in w2v
# word macbeth not in w2v
# word shakespeare's not in w2v
# word 3000 not in w2v
# word 1968 not in w2v
# word to<br not in w2v
# word huston not in w2v
# word thoughtprovoking not in w2v
# word />ok not in w2v
# word show" not in w2v
# word 'em not in w2v
# word about<br not in w2v
# word barrymore not in w2v
# word husband's not in w2v
# word />rating not in w2v
# word programme not in w2v
# word 1983 not in w2v
# word world" not in w2v
# word other<br not in w2v
# word realised not in w2v
# word />title not in w2v
# word />please not in w2v
# word favour not in w2v
# word ever! not in w2v
# word out" not in w2v
# word "la not in w2v
# word 1990 not in w2v
# word made<br not in w2v
# word *1/2 not in w2v
# word 1970 not in w2v
# word "black not in w2v
# word 1981 not in w2v
# word time" not in w2v
# word role<br not in w2v
# word bettie not in w2v
# word 1940s not in w2v
# word anyone's not in w2v
# word minutes<br not in w2v
# word it`s not in w2v
# word 1969 not in w2v
# word />many not in w2v
# word foxx not in w2v
# word "just not in w2v
# word 1980's not in w2v
# word heston not in w2v
# word cassavetes not in w2v
# word 13th not in w2v
# word all! not in w2v
# word ritter not in w2v
# word />that's not in w2v
# word anyway<br not in w2v
# word disney's not in w2v
# word />these not in w2v
# word them? not in w2v
# word mildred not in w2v
# word day<br not in w2v
# word girl" not in w2v
# word 23 not in w2v
# word up" not in w2v
# word />having not in w2v
# word gere not in w2v
# word wellmade not in w2v
# word argento not in w2v
# word 1978 not in w2v
# word #1 not in w2v
# word people" not in w2v
# word falk not in w2v
# word />though not in w2v
# word lee's not in w2v
# word "movie" not in w2v
# word quentin not in w2v
# word 70 not in w2v
# word 9/11 not in w2v
# word quaid not in w2v
# word cushing not in w2v
# word 1982 not in w2v
# word comedy<br not in w2v
# word son's not in w2v
# word 1988 not in w2v
# word guy" not in w2v
# word 90s not in w2v
# word errol not in w2v
# word miyazaki not in w2v
# word do? not in w2v
# word mitchum not in w2v
# word script<br not in w2v
# word away<br not in w2v
# word wellwritten not in w2v
# word />very not in w2v
# word "b" not in w2v
# word bad! not in w2v
# word paxton not in w2v
# word house" not in w2v
# word />great not in w2v
# word out! not in w2v
# word them! not in w2v
# word 1945 not in w2v
# word pfeiffer not in w2v
# word dillon not in w2v
# word "house not in w2v
# word fiancã© not in w2v
# word />is not in w2v
# word denzel not in w2v
# word "big not in w2v
# word jackson's not in w2v
# word rourke not in w2v
# word bmovies not in w2v
# word so<br not in w2v
# word "real" not in w2v
# word 1998 not in w2v
# word ending<br not in w2v
# word now<br not in w2v
# word "well not in w2v
# word wrong<br not in w2v
# word widmark not in w2v
# word together<br not in w2v
# word romero not in w2v
# word good" not in w2v
# word orson not in w2v
# word colours not in w2v
# word film" not in w2v
# word 21st not in w2v
# word 1994 not in w2v
# word 1987 not in w2v
# word do<br not in w2v
# word love<br not in w2v
# word man<br not in w2v
# word "get not in w2v
# word busey not in w2v
# word !! not in w2v
# word "one not in w2v
# word ford's not in w2v
# word "who not in w2v
# word thing<br not in w2v
# word 1974 not in w2v
# word 1984 not in w2v
# word welldone not in w2v
# word irene not in w2v
# word />here not in w2v
# word story's not in w2v
# word corman not in w2v
# word place<br not in w2v
# word viewer's not in w2v
# word night" not in w2v
# word lucille not in w2v
# word "they not in w2v
# word there? not in w2v
# word up! not in w2v
# word miike not in w2v
# word itself<br not in w2v
# word 1960's not in w2v
# word 1986 not in w2v
# word actors' not in w2v
# word acting<br not in w2v
# word down<br not in w2v
# word chaplin's not in w2v
# word "do not in w2v
# word "love not in w2v
# word fun<br not in w2v
# word thing" not in w2v
# word huh? not in w2v
# word />okay not in w2v
# word centre not in w2v
# word />5 not in w2v
# word 1930's not in w2v
# word carpenter's not in w2v
# word herzog not in w2v
# word astaire not in w2v
# word performance<br not in w2v
# word marlon not in w2v
# word though<br not in w2v
# word laurence not in w2v
# word 1933 not in w2v
# word family<br not in w2v
# word killer's not in w2v
# word />once not in w2v
# word duvall not in w2v
# word />i'll not in w2v
# word daughter's not in w2v
# word blood" not in w2v
# word clive not in w2v
# word ever<br not in w2v
# word dvd's not in w2v
# word spoilers<br not in w2v
# word audience<br not in w2v
# word />john not in w2v
# word 40s not in w2v
# word />i'd not in w2v
# word `the not in w2v
# word devito not in w2v
# word juliette not in w2v
# word />7/10 not in w2v
# word "good" not in w2v
# word ingrid not in w2v
# word soso not in w2v
# word costello not in w2v
# word />bottom not in w2v
# word else<br not in w2v
# word />two not in w2v
# word 22 not in w2v
# word about? not in w2v
# word "death not in w2v
# word 1989 not in w2v
# word elvira not in w2v
# word sense<br not in w2v
# word here? not in w2v
# word 1940 not in w2v
# word brother's not in w2v
# word her? not in w2v
# word 1939 not in w2v
# word right<br not in w2v
# word '70s not in w2v
# word axe not in w2v
# word drivein not in w2v
# word alvin not in w2v
# word kurtz not in w2v
# word him! not in w2v
# word />see not in w2v
# word "that not in w2v
# word death<br not in w2v
# word wellacted not in w2v
# word fiancã©e not in w2v
# word day" not in w2v
# word 1976 not in w2v
# word point<br not in w2v
# word say? not in w2v
# word !!! not in w2v
# word beatty not in w2v
# word />4/10 not in w2v
# word basinger not in w2v
# word brosnan not in w2v
# word kermit not in w2v
# word />where not in w2v
# word />she not in w2v
# word 	 not in w2v
# word haines not in w2v
# word />8/10 not in w2v
# word 1000 not in w2v
# word cinema<br not in w2v
# word palance not in w2v
# word belushi not in w2v
# word nicolas not in w2v
# word selfindulgent not in w2v
# word through<br not in w2v
# word wayne's not in w2v
# word 1985 not in w2v
# word 19 not in w2v
# word mind<br not in w2v
# word "night not in w2v
# word 1977 not in w2v
# word seen! not in w2v
# word />next not in w2v
# word swayze not in w2v
# word disappointed<br not in w2v
# word />3/10 not in w2v
# word />let's not in w2v
# word gundam not in w2v
# word firstrate not in w2v
# word ponyo not in w2v
# word 1991 not in w2v
# word experience<br not in w2v
# word great<br not in w2v
# word christy not in w2v
# word person's not in w2v
# word 90% not in w2v
# word />yet not in w2v
# word of<br not in w2v
# word shatner not in w2v
# word best<br not in w2v
# word 10<br not in w2v
# word "not not in w2v
# word for<br not in w2v
# word 1990s not in w2v
# word paltrow not in w2v
# word affleck not in w2v
# word t&a not in w2v
# word 1959 not in w2v
# word hartley not in w2v
# word cast<br not in w2v
# word carell not in w2v
# word 30s not in w2v
# word others<br not in w2v
# word fontaine not in w2v
# word 'cause not in w2v
# word done<br not in w2v
# word men" not in w2v
# word knightley not in w2v
# word kline not in w2v
# word later<br not in w2v
# word characterisation not in w2v
# word />his not in w2v
# word />7 not in w2v
# word us<br not in w2v
# word depardieu not in w2v
# word doris not in w2v
# word dunne not in w2v
# word something<br not in w2v
# word />only not in w2v
# word funny! not in w2v
# word "look not in w2v
# word story? not in w2v
# word polanski not in w2v
# word />every not in w2v
# word over<br not in w2v
# word "bad" not in w2v
# word />basically not in w2v
# word 2008 not in w2v
# word did<br not in w2v
# word hepburn not in w2v
# word know<br not in w2v
# word back<br not in w2v
# word again" not in w2v
# word are<br not in w2v
# word audrey not in w2v
# word theatres not in w2v
# word kinski not in w2v
# word africanamerican not in w2v
# word gein not in w2v
# word me? not in w2v
# word deniro not in w2v
# word "when not in w2v
# word dolph not in w2v
# word />sure not in w2v
# word />good not in w2v
# word boring<br not in w2v
# word entertaining<br not in w2v
# word hayworth not in w2v
# word wrong! not in w2v
# word nolte not in w2v
# word cassidy not in w2v
# word be? not in w2v
# word cares? not in w2v
# word 200 not in w2v
# word crap<br not in w2v
# word />since not in w2v
# word 1975 not in w2v
# word whoopi not in w2v
# word 101 not in w2v
# word zane not in w2v
# word 30's not in w2v
# word actors<br not in w2v
# word ebert not in w2v
# word street" not in w2v
# word mclaglen not in w2v
# word days<br not in w2v
# word />10/10 not in w2v
# word "where not in w2v
# word bacall not in w2v
# word "new not in w2v
# word it!<br not in w2v
# word audience's not in w2v
# word writer's not in w2v
# word lumet not in w2v
# word 1953 not in w2v
# word before<br not in w2v
# word 1950 not in w2v
# word madsen not in w2v
# word is! not in w2v
# word visconti not in w2v
# word fulci's not in w2v
# word book<br not in w2v
# word lundgren not in w2v
# word />what's not in w2v
# word anyone? not in w2v
# word history<br not in w2v
# word raines not in w2v
# word 75 not in w2v
# word interesting<br not in w2v
# word fun! not in w2v
# word fiennes not in w2v
# word '80s not in w2v
# word 28 not in w2v
# word "little not in w2v
# word mencia not in w2v
# word gamera not in w2v
# word tv's not in w2v
# word coburn not in w2v
# word hero's not in w2v
# word kinnear not in w2v
# word awful<br not in w2v
# word time? not in w2v
# word kubrick's not in w2v
# word othello not in w2v
# word worse<br not in w2v
# word "mr not in w2v
# word finney not in w2v
# word "let's not in w2v
# word 21 not in w2v
# word hawke not in w2v
# word eastwood's not in w2v
# word 40's not in w2v
# word the<br not in w2v
# word />besides not in w2v
# word amitabh not in w2v
# word malkovich not in w2v
# word malone not in w2v
# word />*** not in w2v
# word himself<br not in w2v
# word />meanwhile not in w2v
# word happen<br not in w2v
# word tongueincheek not in w2v
# word vincenzo not in w2v
# word roles<br not in w2v
# word verhoeven not in w2v
# word kelly's not in w2v
# word allen's not in w2v
# word flick<br not in w2v
# word keaton's not in w2v
# word "dead not in w2v
# word gromit not in w2v
# word "plot" not in w2v
# word idea<br not in w2v
# word hitler's not in w2v
# word isabelle not in w2v
# word myrna not in w2v
# word 300 not in w2v
# word thinking? not in w2v
# word "best not in w2v
# word redford not in w2v
# word today<br not in w2v
# word 1992 not in w2v
# word granger not in w2v
# word blackandwhite not in w2v
# word it!!! not in w2v
# word 1955 not in w2v
# word />because not in w2v
# word "man not in w2v
# word money<br not in w2v
# word edith not in w2v
# word stallone not in w2v
# word aztec not in w2v
# word "comedy" not in w2v
# word charlie's not in w2v
# word 1934 not in w2v
# word wars" not in w2v
# word moore's not in w2v
# word baby" not in w2v
# word 1936 not in w2v
# word keanu not in w2v
# word tierney not in w2v
# word watching<br not in w2v
# word veronika not in w2v
# word 1960 not in w2v
# word dvd<br not in w2v
# word />highly not in w2v
# word 1944 not in w2v
# word />everything not in w2v
# word days" not in w2v
# word />grade not in w2v
# word />8 not in w2v
# word now" not in w2v
# word "you're not in w2v
# word penelope not in w2v
# word 'i not in w2v
# word grier not in w2v
# word liveaction not in w2v
# word />acting not in w2v
# word anyway? not in w2v
# word vaughn not in w2v
# word ustinov not in w2v
# word death" not in w2v
# word austen's not in w2v
# word zellweger not in w2v
# word see<br not in w2v
# word movies! not in w2v
# word again? not in w2v
# word biko not in w2v
# word enough<br not in w2v
# word lorre not in w2v
# word 'a not in w2v
# word gielgud not in w2v
# word />watching not in w2v
# word wood's not in w2v
# word job<br not in w2v
# word cheadle not in w2v
# word genre<br not in w2v
# word milland not in w2v
# word things<br not in w2v
# word ricci not in w2v
# word reason<br not in w2v
# word stuff<br not in w2v
# word david's not in w2v
# word />let not in w2v
# word scott's not in w2v
# word sister's not in w2v
# word lives<br not in w2v
# word antonioni not in w2v
# word one" not in w2v
# word coppola not in w2v
# word john's not in w2v
# word city" not in w2v
# word elijah not in w2v
# word his/her not in w2v
# word here! not in w2v
# word arquette not in w2v
# word lestat not in w2v
# word o'toole not in w2v
# word 1930 not in w2v
# word lansbury not in w2v
# word chaney not in w2v
# word stars<br not in w2v
# word 1940's not in w2v
# word part<br not in w2v
# word 85 not in w2v
# word fishburne not in w2v
# word lupino not in w2v
# word dien not in w2v
# word lynch's not in w2v
# word around<br not in w2v
# word 1967 not in w2v
# word kristofferson not in w2v
# word scorsese not in w2v
# word costner not in w2v
# word sh*t not in w2v
# word 1957 not in w2v
# word 1948 not in w2v
# word stupid<br not in w2v
# word deanna not in w2v
# word />unlike not in w2v
# word 1943 not in w2v
# word show! not in w2v
# word on? not in w2v
# word eleanor not in w2v
# word />second not in w2v
# word own<br not in w2v
# word judgement not in w2v
# word realises not in w2v
# word paulie not in w2v
# word melville not in w2v
# word plot? not in w2v
# word monkees not in w2v
# word â not in w2v
# word marlow not in w2v
# word year<br not in w2v
# word />both not in w2v
# word 1942 not in w2v
# word coen not in w2v
# word elmer not in w2v
# word "happy not in w2v
# word from? not in w2v
# word classic<br not in w2v
# word war" not in w2v
# word klaus not in w2v
# word people? not in w2v
# word   not in w2v
# word now! not in w2v
# word "to not in w2v
# word timberlake not in w2v
# word o'hara not in w2v
# word rickman not in w2v
# word boy" not in w2v
# word />10 not in w2v
# word "is not in w2v
# word truman not in w2v
# word bakshi not in w2v
# word ii" not in w2v
# word adele not in w2v
# word all? not in w2v
# word from<br not in w2v
# word moviei not in w2v
# word rukh not in w2v
# word earth" not in w2v
# word music<br not in w2v
# word lucio not in w2v
# word loretta not in w2v
# word />david not in w2v
# word nielsen not in w2v
# word for? not in w2v
# word back! not in w2v
# word />much not in w2v
# word away! not in w2v
# word it!! not in w2v
# word moon" not in w2v
# word life! not in w2v
# word space" not in w2v
# word "on not in w2v
# word "that's not in w2v
# word enjoy! not in w2v
# word 18th not in w2v
# word "evil not in w2v
# word is? not in w2v
# word sheba not in w2v
# word jack's not in w2v
# word soylent not in w2v
# word tilly not in w2v
# word ramon not in w2v
# word man' not in w2v
# word directtovideo not in w2v
# word didnt not in w2v
# word dad's not in w2v
# word #2 not in w2v
# word itâ´s not in w2v
# word 1966 not in w2v
# word 1932 not in w2v
# word geraldine not in w2v
# word more! not in w2v
# word />seriously not in w2v
# word 007 not in w2v
# word well! not in w2v
# word rathbone not in w2v
# word barbra not in w2v
# word burton's not in w2v
# word here; not in w2v
# word "real not in w2v
# word leland not in w2v
# word original<br not in w2v
# word cancelled not in w2v
# word demille not in w2v
# word farley not in w2v
# word rhett not in w2v
# word movie!!! not in w2v
# word />people not in w2v
# word picture<br not in w2v
# word 1951 not in w2v
# word eyre not in w2v
# word one? not in w2v
# word niven not in w2v
# word />before not in w2v
# word marvellous not in w2v
# word 10! not in w2v
# word "he not in w2v
# word episode<br not in w2v
# word godard not in w2v
# word />later not in w2v
# word game<br not in w2v
# word girls" not in w2v
# word "old not in w2v
# word />technically not in w2v
# word ramones not in w2v
# word    not in w2v
# word willard not in w2v
# word believable<br not in w2v
# word 3" not in w2v
# word selfcentered not in w2v
# word thurman not in w2v
# word "what's not in w2v
# word poirot not in w2v
# word rowlands not in w2v
# word does<br not in w2v
# word bergman's not in w2v
# word prue not in w2v
# word fairbanks not in w2v
# word swanson not in w2v
# word sylvester not in w2v
# word arkin not in w2v
# word face<br not in w2v
# word poitier not in w2v
# word />sorry not in w2v
# word />mr not in w2v
# word sirk not in w2v
# word 1990's not in w2v
# word scheider not in w2v
# word guys" not in w2v
# word jane's not in w2v
# word "dark not in w2v
# word />aside not in w2v
# word 1941 not in w2v
# word out? not in w2v
# word stewart's not in w2v
# word moriarty not in w2v
# word mcqueen not in w2v
# word awful! not in w2v
# word 500 not in w2v
# word segal not in w2v
# word dietrich not in w2v
# word redgrave not in w2v
# word kilmer not in w2v
# word "horror" not in w2v
# word fellini not in w2v
# word clarence not in w2v
# word geoffrey not in w2v
# word preminger not in w2v
# word movie!! not in w2v
# word 1947 not in w2v
# word moments<br not in w2v
# word action<br not in w2v
# word this; not in w2v
# word glenda not in w2v
# word />9/10 not in w2v
# word harriet not in w2v
# word funny? not in w2v
# word eisenstein not in w2v
# word vinnie not in w2v
# word zombi not in w2v
# word lukas not in w2v
# word era<br not in w2v
# word attenborough not in w2v
# word />which not in w2v
# word evil" not in w2v
# word palma not in w2v
# word />here's not in w2v
# word movies" not in w2v
# word way! not in w2v
# word />sadly not in w2v
# word back" not in w2v
# word park" not in w2v
# word 26 not in w2v
# word "king not in w2v
# word deneuve not in w2v
# word ***spoilers*** not in w2v
# word "special not in w2v
# word there! not in w2v
# word here" not in w2v
# word is; not in w2v
# word dolemite not in w2v
# word theodore not in w2v
# word />who not in w2v
# word />actually not in w2v
# word />note not in w2v
# word home<br not in w2v
# word shemp not in w2v
# word alexandre not in w2v
# word smith's not in w2v
# word />definitely not in w2v
# word michael's not in w2v
# word conroy not in w2v
# word war<br not in w2v
# word writerdirector not in w2v
# word winchester not in w2v
# word "i'll not in w2v
# word ocean's not in w2v
# word />6 not in w2v
# word henson not in w2v
# word />final not in w2v
# word "action" not in w2v
# word b&w not in w2v
# word "but not in w2v
# word career<br not in w2v
# word lorenzo not in w2v
# word capshaw not in w2v
# word 27 not in w2v
# word life? not in w2v
# word estevez not in w2v
# word gwyneth not in w2v
# word like<br not in w2v
# word goldblum not in w2v
# word byrne not in w2v
# word know? not in w2v
# word ratso not in w2v
# word earth's not in w2v
# word sydow not in w2v
# word dafoe not in w2v
# word bug's not in w2v
# word />instead not in w2v
# word woman" not in w2v
# word />directed not in w2v
# word />robert not in w2v
# word />those not in w2v
# word />** not in w2v
# word cecil not in w2v
# word />more not in w2v
# word precode not in w2v
# word dario not in w2v
# word />bad not in w2v
# word reiser not in w2v
# word long<br not in w2v
# word straighttovideo not in w2v
# word eyes<br not in w2v
# word selleck not in w2v
# word boys" not in w2v
# word wayans not in w2v
# word 0/10 not in w2v
# word mcdowell not in w2v
# word possible<br not in w2v
# word talbot not in w2v
# word />secondly not in w2v
# word bynes not in w2v
# word line<br not in w2v
# word horror" not in w2v
# word home" not in w2v
# word jacobi not in w2v
# word bunuel not in w2v
# word suchet not in w2v
# word city's not in w2v
# word natasha not in w2v
# word "midnight not in w2v
# word />michael not in w2v
# word fleischer not in w2v
# word priscilla not in w2v
# word way" not in w2v
# word carlyle not in w2v
# word freddy's not in w2v
# word o'neill not in w2v
# word hadley not in w2v
# word />**** not in w2v
# word night<br not in w2v
# word cronenberg not in w2v
# word director/writer not in w2v
# word kurosawa not in w2v
# word jagger not in w2v
# word hilarious! not in w2v
# word soderbergh not in w2v
# word langdon not in w2v
# word altman's not in w2v
# word amrita not in w2v
# word themselves<br not in w2v
# word />did not in w2v
# word wilson's not in w2v
# word englund not in w2v
# word rko not in w2v
# word chiba not in w2v
# word instead<br not in w2v
# word colman not in w2v
# word years! not in w2v
# word story! not in w2v
# word 1949 not in w2v
# word point? not in w2v
# word alain not in w2v
# word made? not in w2v
# word />go not in w2v
# word favourites not in w2v
# word actor<br not in w2v
# word brothers' not in w2v
# word vargas not in w2v
# word gotham not in w2v
# word 1920s not in w2v
# word bad? not in w2v
# word />or not in w2v
# word />2/10 not in w2v
# word not? not in w2v
# word faye not in w2v
# word "war not in w2v
# word bsg not in w2v
# word better! not in w2v
# word mathieu not in w2v
# word 1958 not in w2v
# word zoey not in w2v
# word w/ not in w2v
# word quigley not in w2v
# word kingsley not in w2v
# word "an not in w2v
# word mess<br not in w2v
# word 250 not in w2v
# word bgrade not in w2v
# word 51 not in w2v
# word govinda not in w2v
# word branagh's not in w2v
# word />anyone not in w2v
# word cheech not in w2v
# word throughout<br not in w2v
# word 1956 not in w2v
# word silverman not in w2v
# word another<br not in w2v
# word up? not in w2v
# word 'n' not in w2v
# word cinema's not in w2v
# word performances<br not in w2v
# word get's not in w2v
# word 1938 not in w2v
# word edmund not in w2v
# word jones' not in w2v
# word />richard not in w2v
# word hilarious<br not in w2v
# word />speaking not in w2v
# word xfiles not in w2v
# word 'what not in w2v
# word right! not in w2v
# word />nothing not in w2v
# word movieand not in w2v
# word miyazaki's not in w2v
# word beckinsale not in w2v
# word "hero" not in w2v
# word was! not in w2v
# word slowmoving not in w2v
# word direction<br not in w2v
# word "white not in w2v
# word marisa not in w2v
# word />really not in w2v
# word />story not in w2v
# word amazing! not in w2v
# word wwi not in w2v
# word takashi not in w2v
# word travelling not in w2v
# word duchovny not in w2v
# word brynner not in w2v
# word movie!<br not in w2v
# word gilmore not in w2v
# word welles' not in w2v
# word end? not in w2v
# word see! not in w2v
# word actors/actresses not in w2v
# word marlene not in w2v
# word atwill not in w2v
# word wrong? not in w2v
# word />being not in w2v
# word delon not in w2v
# word massacre" not in w2v
# word haruhi not in w2v
# word />apart not in w2v
# word arnie not in w2v
# word anderson's not in w2v
# word beethoven not in w2v
# word keira not in w2v
# word level<br not in w2v
# word />take not in w2v
# word schreiber not in w2v
# word rachael not in w2v
# word horrible! not in w2v
# word />best not in w2v
# word ago<br not in w2v
# word terrible<br not in w2v
# word caligula not in w2v
# word krueger not in w2v
# word kersey not in w2v
# word town's not in w2v
# word good; not in w2v
# word 1965 not in w2v
# word brilliant! not in w2v
# word cassel not in w2v
# word 48 not in w2v
# word farscape not in w2v
# word connery's not in w2v
# word case<br not in w2v
# word perlman not in w2v
# word course<br not in w2v
# word him; not in w2v
# word acting? not in w2v
# word agatha not in w2v
# word time; not in w2v
# word train" not in w2v
# word period<br not in w2v
# word slowmotion not in w2v
# word go<br not in w2v
# word />without not in w2v
# word real<br not in w2v
# word />1/10 not in w2v
# word 1946 not in w2v
# word recognise not in w2v
# word sg1 not in w2v
# word style<br not in w2v
# word nothing<br not in w2v
# word one; not in w2v
# word then<br not in w2v
# word nevsky not in w2v
# word naschy not in w2v
# word howard's not in w2v
# word wellcrafted not in w2v
# word end! not in w2v
# word cleopatra not in w2v
# word crispin not in w2v
# word galactica not in w2v
# word say<br not in w2v
# word "there's not in w2v
# word 1962 not in w2v
# word he/she not in w2v
# word horror<br not in w2v
# word knows? not in w2v
# word spielberg's not in w2v
# word it?<br not in w2v
# word murphy's not in w2v
# word daylewis not in w2v
# word carole not in w2v
# word yourself<br not in w2v
# word that" not in w2v
# word valerie not in w2v
# word tomei not in w2v
# word 1964 not in w2v
# word seinfeld not in w2v
# word drama<br not in w2v
# word />plot not in w2v
# word huppert not in w2v
# word ray's not in w2v
# word benoit not in w2v
# word movie' not in w2v
# word $5 not in w2v
# word />again not in w2v
# word woman<br not in w2v
# word matter<br not in w2v
# word wind" not in w2v
# word "go not in w2v
# word effects<br not in w2v
# word 1963 not in w2v
# word "le not in w2v
# word lili not in w2v
# word ealing not in w2v
# word gypo not in w2v
# word god! not in w2v
# word iturbi not in w2v
# word paresh not in w2v
# word pickford not in w2v
# word on" not in w2v
# word "blood not in w2v
# word keitel not in w2v
# word trex not in w2v
# word sciencefiction not in w2v
# word "twist" not in w2v
# word />during not in w2v
# word wendigo not in w2v
# word heaven" not in w2v
# word heaven's not in w2v
# word neighbours not in w2v
# word movies? not in w2v
# word />too not in w2v
# word friends<br not in w2v
# word />ultimately not in w2v
# word there`s not in w2v
# word isabel not in w2v
# word children<br not in w2v
# word her! not in w2v
# word family" not in w2v
# word gyllenhaal not in w2v
# word ironside not in w2v
# word sondra not in w2v
# word "friday not in w2v
# word come<br not in w2v
# word be! not in w2v
# word 95 not in w2v
# word high" not in w2v
# word victim's not in w2v
# word past<br not in w2v
# word !<br not in w2v
# word binoche not in w2v
# word cortez not in w2v
# word zorro not in w2v
# word macarthur not in w2v
# word director<br not in w2v
# word masterson not in w2v
# word watch! not in w2v
# word dicaprio not in w2v
# word />spoiler not in w2v
# word pryor not in w2v
# word gustav not in w2v
# word josie not in w2v
# word help<br not in w2v
# word stalingrad not in w2v
# word this" not in w2v
# word stone's not in w2v
# word schrader not in w2v
# word dudikoff not in w2v
# word zizek not in w2v
# word society's not in w2v
# word linnea not in w2v
# word off! not in w2v
# word "friends" not in w2v
# word think<br not in w2v
# word crap! not in w2v
# word ones<br not in w2v
# word anything<br not in w2v
# word filmmaker's not in w2v
# word tyrone not in w2v
# word "plan not in w2v
# word "never not in w2v
# word die" not in w2v
# word reasons<br not in w2v
# word shot<br not in w2v
# word "family not in w2v
# word elisha not in w2v
# word zucco not in w2v
# word raimi not in w2v
# word />spoilers not in w2v
# word "high not in w2v
# word place? not in w2v
# word future<br not in w2v
# word welldeveloped not in w2v
# word annoying<br not in w2v
# word />worth not in w2v
# word "psycho" not in w2v
# word more? not in w2v
# word '80's not in w2v
# word cinemax not in w2v
# word blondell not in w2v
# word bergen not in w2v
# word have<br not in w2v
# word "yes not in w2v
# word hackman not in w2v
# word ripley not in w2v
# word honour not in w2v
# word two<br not in w2v
# word tv<br not in w2v
# word alejandro not in w2v
# word "1" not in w2v
# word match<br not in w2v
# word kazan not in w2v
# word start? not in w2v
# word beowulf not in w2v
# word "of not in w2v
# word wynorski not in w2v
# word it?" not in w2v
# word miike's not in w2v
# word helsing not in w2v
# word tarantino's not in w2v
# word />eye not in w2v
# word "lost not in w2v
# word "acting" not in w2v
# word characters; not in w2v
# word colourful not in w2v
# word capote not in w2v
# word harry's not in w2v
# word selfabsorbed not in w2v
# word blandings not in w2v
# word melvyn not in w2v
# word heart<br not in w2v
# word bad; not in w2v
# word 180 not in w2v
# word riddick not in w2v
# word minnelli not in w2v
# word demme not in w2v
# word />about not in w2v
# word turturro not in w2v
# word julianne not in w2v
# word well; not in w2v
# word />look not in w2v
# word allamerican not in w2v
# word man! not in w2v
# word away" not in w2v
# word "art" not in w2v
# word 64 not in w2v
# word hartley's not in w2v
# word icet not in w2v
# word raoul not in w2v
# word harlan not in w2v
# word milligan not in w2v
# word nathaniel not in w2v
# word midler not in w2v
# word />never not in w2v
# word massey not in w2v
# word 2009 not in w2v
# word "red not in w2v
# word 39 not in w2v
# word dassin not in w2v
# word mendes not in w2v
# word series' not in w2v
# word bigbudget not in w2v
# word sykes not in w2v
# word savalas not in w2v
# word />three not in w2v
# word laugh<br not in w2v
# word chan's not in w2v
# word dressler not in w2v
# word gershwin not in w2v
# word 911 not in w2v
# word willem not in w2v
# word humor<br not in w2v
# word lines<br not in w2v
# word patton not in w2v
# word "mystery not in w2v
# word />unless not in w2v
# word />everyone not in w2v
# word see" not in w2v
# word 400 not in w2v
# word reginald not in w2v
# word />was not in w2v
# word romero's not in w2v
# word 1954 not in w2v
# word radha not in w2v
# word "be not in w2v
# word witherspoon not in w2v
# word "mad not in w2v
# word />none not in w2v
# word 1931 not in w2v
# word armand not in w2v
# word bythenumbers not in w2v
# word heche not in w2v
# word a<br not in w2v
# word effort<br not in w2v
# word sergei not in w2v
# word morgana not in w2v
# word made! not in w2v
# word lot<br not in w2v
# word twodimensional not in w2v
# word 99 not in w2v
# word island" not in w2v
# word d'amato not in w2v
# word classic! not in w2v
# word alone<br not in w2v
# word laughoutloud not in w2v
# word reality<br not in w2v
# word dreyfuss not in w2v
# word />our not in w2v
# word sigourney not in w2v
# word hasselhoff not in w2v
# word rrated not in w2v
# word sabrina not in w2v
# word />recommended not in w2v
# word gilliam not in w2v
# word forsythe not in w2v
# word ted's not in w2v
# word "from not in w2v
# word bardem not in w2v
# word henriksen not in w2v
# word dahmer not in w2v
# word nazi's not in w2v
# word />back not in w2v
# word $10 not in w2v
# word rudolph not in w2v
# word care<br not in w2v
# word oppenheimer not in w2v
# word "sex not in w2v
# word mcdermott not in w2v
# word johansson not in w2v
# word hollywood<br not in w2v
# word dead' not in w2v
# word lady's not in w2v
# word argento's not in w2v
# word carax not in w2v
# word "thriller" not in w2v
# word terrible! not in w2v
# word yet<br not in w2v
# word entertainment<br not in w2v
# word suzy not in w2v
# word same<br not in w2v
# word connelly not in w2v
# word grady not in w2v
# word kiefer not in w2v
# word father<br not in w2v
# word neeson not in w2v
# word "blue not in w2v
# word oscarwinning not in w2v
# word frederic not in w2v
# word brigitte not in w2v
# word version<br not in w2v
# word />tom not in w2v
# word pacino's not in w2v
# word />given not in w2v
# word myra not in w2v
# word gena not in w2v
# word garbage<br not in w2v
# word game" not in w2v
# word budget<br not in w2v
# word programmes not in w2v
# word franz not in w2v
# word gretchen not in w2v
# word face" not in w2v
# word kolchak not in w2v
# word />her not in w2v
# word dialogue<br not in w2v
# word "citizen not in w2v
# word country's not in w2v
# word why<br not in w2v
# word house<br not in w2v
# word chance<br not in w2v
# word maltin not in w2v
# word good? not in w2v
# word seagal's not in w2v
# word gillian not in w2v
# word tatum not in w2v
# word line" not in w2v
# word antoine not in w2v
# word $100 not in w2v
# word deadon not in w2v
# word dickinson not in w2v
# word begin? not in w2v
# word naã¯ve not in w2v
# word production<br not in w2v
# word story; not in w2v
# word />any not in w2v
# word liotta not in w2v
# word "come not in w2v
# word cowboy" not in w2v
# word disappointment<br not in w2v
# word tony's not in w2v
# word they? not in w2v
# word davis' not in w2v
# word works<br not in w2v
# word "we're not in w2v
# word giovanni not in w2v
# word beast" not in w2v
# word northam not in w2v
# word them; not in w2v
# word 1937 not in w2v
# word films! not in w2v
# word />along not in w2v
# word agnes not in w2v
# word people! not in w2v
# word alone" not in w2v
# word emmanuelle not in w2v
# word bava not in w2v
# word "actors" not in w2v
# word werner not in w2v
# word featurelength not in w2v
# word situation<br not in w2v
# word blaise not in w2v
# word forever<br not in w2v
# word down" not in w2v
# word "dirty not in w2v
# word seuss not in w2v
# word centres not in w2v
# word />based not in w2v
# word really? not in w2v
# word laughs<br not in w2v
# word stockwell not in w2v
# word can<br not in w2v
# word rawal not in w2v
# word esther not in w2v
# word rooker not in w2v
# word pegg not in w2v
# word pertwee not in w2v
# word cedric not in w2v
# word theron not in w2v
# word renoir not in w2v
# word kane" not in w2v
# word masterpiece<br not in w2v
# word stopmotion not in w2v
# word "full not in w2v
# word awesome! not in w2v
# word shakespearean not in w2v
# word do! not in w2v
# word name<br not in w2v
# word and<br not in w2v
# word its' not in w2v
# word geena not in w2v
# word halfbaked not in w2v
# word sammo not in w2v
# word caruso not in w2v
# word deol not in w2v
# word sarne not in w2v
# word times" not in w2v
# word anymore<br not in w2v
# word />peter not in w2v
# word recognised not in w2v
# word caddyshack not in w2v
# word />honestly not in w2v
# word 34 not in w2v
# word author's not in w2v
# word />thank not in w2v
# word kid" not in w2v
# word sam's not in w2v
# word josã© not in w2v
# word fire" not in w2v
# word cage's not in w2v
# word "and not in w2v
# word humphrey not in w2v
# word spoton not in w2v
# word scene's not in w2v
# word mulder not in w2v
# word while<br not in w2v
# word now? not in w2v
# word life; not in w2v
# word "out not in w2v
# word d'angelo not in w2v
# word martino not in w2v
# word brown's not in w2v
# word comedy? not in w2v
# word schumacher not in w2v
# word collette not in w2v
# word longoria not in w2v
# word callahan not in w2v
# word machine" not in w2v
# word />someone not in w2v
# word interest<br not in w2v
# word times! not in w2v
# word />'the not in w2v
# word harlow not in w2v
# word dance" not in w2v
# word head<br not in w2v
# word filmnoir not in w2v
# word best! not in w2v
# word viewing<br not in w2v
# word popeye not in w2v
# word effects" not in w2v
# word viewer<br not in w2v
# word different<br not in w2v
# word kornbluth not in w2v
# word thing? not in w2v
# word wideeyed not in w2v
# word madonna's not in w2v
# word gulliver not in w2v
# word greenstreet not in w2v
# word person<br not in w2v
# word true<br not in w2v
# word filmthe not in w2v
# word buddy's not in w2v
# word finlay not in w2v
# word paul's not in w2v
# word himesh not in w2v
# word women<br not in w2v
# word "serious" not in w2v
# word job! not in w2v
# word hell" not in w2v
# word imdb's not in w2v
# word timon not in w2v
# word juhi not in w2v
# word darius not in w2v
# word 99% not in w2v
# word camera<br not in w2v
# word "i've not in w2v
# word ways<br not in w2v
# word beginning<br not in w2v
# word />set not in w2v
# word brilliant<br not in w2v
# word "story" not in w2v
# word whatsoever<br not in w2v
# word sinatra's not in w2v
# word runofthemill not in w2v
# word />9 not in w2v
# word "alien" not in w2v
# word berenger not in w2v
# word truffaut not in w2v
# word '50s not in w2v
# word there" not in w2v
# word involved<br not in w2v
# word katharine not in w2v
# word "titanic" not in w2v
# word caron not in w2v
# word 56 not in w2v
# word fiction" not in w2v
# word "return not in w2v
# word wahlberg not in w2v
# word bakshi's not in w2v
# word act<br not in w2v
# word 1935 not in w2v
# word />such not in w2v
# word downtoearth not in w2v
# word luzhin not in w2v
# word hamill not in w2v
# word dream" not in w2v
# word aschenbach not in w2v
# word cat" not in w2v
# word hartman not in w2v
# word end" not in w2v
# word opinion<br not in w2v
# word along<br not in w2v
# word danton not in w2v
# word york's not in w2v
# word charlize not in w2v
# word "les not in w2v
# word ending? not in w2v
# word gackt not in w2v
# word hannibal not in w2v
# word s&m not in w2v
# word recommended! not in w2v
# word aiello not in w2v
# word />thanks not in w2v
# word />otherwise not in w2v
# word cassandra not in w2v
# word boyce not in w2v
# word eccleston not in w2v
# word giamatti not in w2v
# word else? not in w2v
# word credits<br not in w2v
# word "home not in w2v
# word "hollywood not in w2v
# word next<br not in w2v
# word city<br not in w2v
# word happened<br not in w2v
# word guy<br not in w2v
# word />fans not in w2v
# word "make not in w2v
# word mother<br not in w2v
# word been<br not in w2v
# word do" not in w2v
# word view<br not in w2v
# word pavarotti not in w2v
# word 's not in w2v
# word taylor's not in w2v
# word cambodia not in w2v
# word />apparently not in w2v
# word really<br not in w2v
# word "she not in w2v
# word sybil not in w2v
# word lost<br not in w2v
# word '60s not in w2v
# word school<br not in w2v
# word macmurray not in w2v
# word quality<br not in w2v
# word boring! not in w2v
# word play<br not in w2v
# word patient" not in w2v
# word pesci not in w2v
# word bit<br not in w2v
# word in? not in w2v
# word day! not in w2v
# word age<br not in w2v
# word flynn's not in w2v
# word club" not in w2v
# word joe's not in w2v
# word company's not in w2v
# word eye" not in w2v
# word tadzio not in w2v
# word tamura not in w2v
# word 20's not in w2v
# word o'connor not in w2v
# word "men not in w2v
# word sequel<br not in w2v
# word "four not in w2v
# word gleason not in w2v
# word know! not in w2v
# word society<br not in w2v
# word rizzo not in w2v
# word ingmar not in w2v
# word aykroyd not in w2v
# word craven's not in w2v
# word flavia not in w2v
# word seriously<br not in w2v
# word calibre not in w2v
# word penn's not in w2v
# word connors not in w2v
# word rohmer not in w2v
# word band's not in w2v
# word muriel not in w2v
# word />nevertheless not in w2v
# word izzard not in w2v
# word lyle not in w2v
# word miriam not in w2v
# word maclean not in w2v
# word mabel not in w2v
# word glamour not in w2v
# word dvd! not in w2v
# word everything<br not in w2v
# word least<br not in w2v
# word excellent<br not in w2v
# word scary<br not in w2v
# word bad" not in w2v
# word />personally not in w2v
# word follow<br not in w2v
# word 1927 not in w2v
# word mind" not in w2v
# word $1 not in w2v
# word astin not in w2v
# word casablanca not in w2v
# word crowe not in w2v
# word carrey's not in w2v
# word all; not in w2v
# word comedy" not in w2v
# word lowrent not in w2v
# word far<br not in w2v
# word olen not in w2v
# word 110 not in w2v
# word mann's not in w2v
# word slowpaced not in w2v
# word b+ not in w2v
# word udo not in w2v
# word epps not in w2v
# word "see not in w2v
# word 1952 not in w2v
# word shawshank not in w2v
# word thriller<br not in w2v
# word monster" not in w2v
# word something? not in w2v
# word example<br not in w2v
# word friends" not in w2v
# word dark" not in w2v
# word "your not in w2v
# word babs not in w2v
# word />last not in w2v
# word studio's not in w2v
# word />obviously not in w2v
# word miller's not in w2v
# word life' not in w2v
# word art<br not in w2v
# word adrienne not in w2v
# word bogosian not in w2v
# word work? not in w2v
# word "baby not in w2v
# word terrence not in w2v
# word linney not in w2v
# word spoiler<br not in w2v
# word world? not in w2v
# word />movie not in w2v
# word review<br not in w2v
# word s**t not in w2v
# word excon not in w2v
# word buscemi not in w2v
# word ullman not in w2v
# word />firstly not in w2v
# word corbin not in w2v
# word play" not in w2v
# word others' not in w2v
# word child" not in w2v
# word $20 not in w2v
# word "for not in w2v
# word joke<br not in w2v
# word farnsworth not in w2v
# word "ok not in w2v
# word flatliners not in w2v
# word rain" not in w2v
# word "life not in w2v
# word way? not in w2v
# word sorvino not in w2v
# word caprica not in w2v
# word ship's not in w2v
# word zone" not in w2v
# word "alien not in w2v
# word water" not in w2v
# word mantegna not in w2v
# word channing not in w2v
# word 88 not in w2v
# word townsend not in w2v
# word cimino not in w2v
# word lanza not in w2v
# word f/x not in w2v
# word adamson not in w2v
# word hawk's not in w2v
# word viggo not in w2v
# word gandolfini not in w2v
# word "normal" not in w2v
# word />lastly not in w2v
# word in" not in w2v
# word phyllis not in w2v
# word characters? not in w2v
# word "once not in w2v
# word video<br not in w2v
# word />probably not in w2v
# word hell<br not in w2v
# word lillian not in w2v
# word 747 not in w2v
# word 86 not in w2v
# word him" not in w2v
# word country<br not in w2v
# word kill" not in w2v
# word he? not in w2v
# word andie not in w2v
# word friend<br not in w2v
# word "young not in w2v
# word gertrude not in w2v
# word "first not in w2v
# word conrad's not in w2v
# word zetajones not in w2v
# word also<br not in w2v
# word helena not in w2v
# word "batman not in w2v
# word characterdriven not in w2v
# word three<br not in w2v
# word shabana not in w2v
# word "he's not in w2v
# word itthe not in w2v
# word atmosphere<br not in w2v
# word moviethe not in w2v
# word off" not in w2v
# word screen! not in w2v
# word visconti's not in w2v
# word needn't not in w2v
# word "last not in w2v
# word />anyways not in w2v
# word plot; not in w2v
# word films; not in w2v
# word thelma not in w2v
# word scenes? not in w2v
# word west" not in w2v
# word williams' not in w2v
# word elisabeth not in w2v
# word b/c not in w2v
# word 65 not in w2v
# word george's not in w2v
# word gossett not in w2v
# word noam not in w2v
# word />things not in w2v
# word thought<br not in w2v
# word "10" not in w2v
# word rosemary's not in w2v
# word "there not in w2v
# word antwone not in w2v
# word song" not in w2v
# word town" not in w2v
# word />throughout not in w2v
# word "funny" not in w2v
# word ' not in w2v
# word star" not in w2v
# word ask? not in w2v
# word satan's not in w2v
# word horror/thriller not in w2v
# word hours<br not in w2v
# word ryan's not in w2v
# word />paul not in w2v
# word carnosaur not in w2v
# word dead<br not in w2v
# word mattei not in w2v
# word hanzo not in w2v
# word blaine not in w2v
# word />their not in w2v
# word before? not in w2v
# word hoffman's not in w2v
# word enjoy<br not in w2v
# word ringwald not in w2v
# word yet? not in w2v
# word nadia not in w2v
# word dukakis not in w2v
# word johnson's not in w2v
# word matinã©e not in w2v
# word enjoyable<br not in w2v
# word fagin not in w2v
# word short<br not in w2v
# word karen's not in w2v
# word ridiculous<br not in w2v
# word women" not in w2v
# word sucks! not in w2v
# word veidt not in w2v
# word sonja not in w2v
# word mishima not in w2v
# word frankenstein's not in w2v
# word "dr not in w2v
# ...
# word "bride not in w2v
# word real? not in w2v
# word favours not in w2v
# word brewster not in w2v
# word outofplace not in w2v
# word years" not in w2v
# word nowhere<br not in w2v
# word depalma not in w2v
# word julie's not in w2v
# word olivier's not in w2v
# word marius not in w2v
# word jim" not in w2v
# word hauer not in w2v
# word "battle not in w2v
# word scenes" not in w2v
# word cool<br not in w2v
# word warner's not in w2v
# word '30s not in w2v
# word healy not in w2v
# word levant not in w2v
# word edwardian not in w2v
# word pitt's not in w2v
# word his<br not in w2v
# word actors? not in w2v
# word after<br not in w2v
# word asano not in w2v
# word feeling<br not in w2v
# word sinclair not in w2v
# word disturbing<br not in w2v
# word game! not in w2v
# word worse! not in w2v
# word she? not in w2v
# word kind<br not in w2v
# word />tony not in w2v
# word rockwell not in w2v
# word caleb not in w2v
# word heigl not in w2v
# word james' not in w2v
# word gough not in w2v
# word australia's not in w2v
# word cleef not in w2v
# word '60's not in w2v
# word girl! not in w2v
# word live<br not in w2v
# word disaster<br not in w2v
# word paine not in w2v
# word emanuelle not in w2v
# word cohen's not in w2v
# word garofalo not in w2v
# word accent<br not in w2v
# word honourable not in w2v
# word />he's not in w2v
# word bukowski not in w2v
# word dawson's not in w2v
# word filmed<br not in w2v
# word />four not in w2v
# word anakin not in w2v
# word se7en not in w2v
# word f16 not in w2v
# word />ah not in w2v
# word timei not in w2v
# word olin not in w2v
# word glover's not in w2v
# word />skip not in w2v
# word 'oh not in w2v
# word memorable<br not in w2v
# word koontz not in w2v
# word realisation not in w2v
# word to" not in w2v
# word nighy not in w2v
# word don't! not in w2v
# word crazy" not in w2v
# word down? not in w2v
# word 1800s not in w2v
# word assante not in w2v
# word office<br not in w2v
# word />"i not in w2v
# word lorne not in w2v
# word />oddly not in w2v
# word impressive<br not in w2v
# word "masters not in w2v
# word lennon's not in w2v
# word "cube" not in w2v
# word sholay not in w2v
# word grace's not in w2v
# word us! not in w2v
# word hopper's not in w2v
# word nimi not in w2v
# word effects? not in w2v
# word hearn not in w2v
# word 87 not in w2v
# word sturges not in w2v
# word pinkett not in w2v
# word deal<br not in w2v
# word elsa not in w2v
# word language<br not in w2v
# word "art not in w2v
# word director! not in w2v
# word strangelove not in w2v
# word />worst not in w2v
# word brigham not in w2v
# word work; not in w2v
# word 29 not in w2v
# word most<br not in w2v
# word logan's not in w2v
# word 1800's not in w2v
# word mystery<br not in w2v
# word "nightmare not in w2v
# word missed<br not in w2v
# word krell not in w2v
# word devil" not in w2v
# word lambs" not in w2v
# word gem<br not in w2v
# word 'movie' not in w2v
# word peebles not in w2v
# word robespierre not in w2v
# word levinson not in w2v
# word paperhouse not in w2v
# word have? not in w2v
# word background<br not in w2v
# word amenabar not in w2v
# word />music not in w2v
# word leatherface not in w2v
# word "hot" not in w2v
# word apart<br not in w2v
# word sternberg not in w2v
# word standards<br not in w2v
# word climax<br not in w2v
# word bhorror not in w2v
# word carlito not in w2v
# word hynkel not in w2v
# word mitchell's not in w2v
# word bulgarian not in w2v
# word walker's not in w2v
# word parsifal not in w2v
# word team<br not in w2v
# word years? not in w2v
# word rating<br not in w2v
# word firstperson not in w2v
# word bagdad not in w2v
# word sheen's not in w2v
# word hero<br not in w2v
# word death? not in w2v
# word stahl not in w2v
# word enrico not in w2v
# word "basic not in w2v
# word expect? not in w2v
# word 78 not in w2v
# word cuthbert not in w2v
# word tassi not in w2v
# word "open not in w2v
# word />have not in w2v
# word ff7 not in w2v
# word danson not in w2v
# word nolte's not in w2v
# word amudha not in w2v
# word lucy's not in w2v
# word africanamericans not in w2v
# word feinstone not in w2v
# word trancers not in w2v
# word ivanna not in w2v
# word day' not in w2v
# word filmmakers' not in w2v
# word "talk not in w2v
# word roebuck not in w2v
# word askey not in w2v
# word deepa not in w2v
# word northfork not in w2v
# word trouble<br not in w2v
# word giancarlo not in w2v
# word carter's not in w2v
# word breckinridge not in w2v
# word capote's not in w2v
# word down! not in w2v
# word creasy not in w2v
# word $150 not in w2v
# word 37 not in w2v
# word trail" not in w2v
# word tobey not in w2v
# word night? not in w2v
# word shapiro not in w2v
# word graffiti" not in w2v
# word hackenstein not in w2v
# word muniz not in w2v
# word "r" not in w2v
# word konkona not in w2v
# word "network" not in w2v
# word "jane not in w2v
# word arbuckle not in w2v
# word bracco not in w2v
# word be; not in w2v
# word point! not in w2v
# word />rather not in w2v
# word ageing not in w2v
# word poseidon not in w2v
# word nimoy not in w2v
# word $3 not in w2v
# word children" not in w2v
# word "paris not in w2v
# word comanche not in w2v
# word fatherson not in w2v
# word />may not in w2v
# word "d" not in w2v
# word better; not in w2v
# word 700 not in w2v
# word "whipped" not in w2v
# word anupam not in w2v
# word date<br not in w2v
# word guys<br not in w2v
# word her; not in w2v
# word />put not in w2v
# word comment<br not in w2v
# word gerda not in w2v
# word vampire's not in w2v
# word mcavoy not in w2v
# word bava's not in w2v
# word stapleton not in w2v
# word much" not in w2v
# word maugham not in w2v
# word freeman's not in w2v
# word $2 not in w2v
# word lerner not in w2v
# word show' not in w2v
# word luciano not in w2v
# word money" not in w2v
# word />stay not in w2v
# word imdb<br not in w2v
# word togar not in w2v
# word "deliverance" not in w2v
# word orwell not in w2v
# word kazaam not in w2v
# word naivetã© not in w2v
# word 'bad' not in w2v
# word "opera" not in w2v
# word />visually not in w2v
# word yugoslavia not in w2v
# word kate's not in w2v
# word susannah not in w2v
# word wife" not in w2v
# word again; not in w2v
# word queen" not in w2v
# word "documentary" not in w2v
# word frank's not in w2v
# word />ms not in w2v
# word clark's not in w2v
# word kids" not in w2v
# word cashin not in w2v
# word lane's not in w2v
# word so? not in w2v
# word />through not in w2v
# word 41 not in w2v
# word jaffe not in w2v
# word ??? not in w2v
# word are! not in w2v
# word />following not in w2v
# word illconceived not in w2v
# word "christmas not in w2v
# word />clearly not in w2v
# word nandita not in w2v
# word />remember not in w2v
# word hero" not in w2v
# word borden not in w2v
# word washington's not in w2v
# word choice<br not in w2v
# word 72 not in w2v
# word this!<br not in w2v
# word "rock not in w2v
# word pendleton not in w2v
# word "killer not in w2v
# word crockett not in w2v
# word 600 not in w2v
# word men' not in w2v
# word black" not in w2v
# word upandcoming not in w2v
# word odyssey" not in w2v
# word greenwich not in w2v
# word this?" not in w2v
# word elvis' not in w2v
# word stanton not in w2v
# word chomsky not in w2v
# word radford not in w2v
# word night' not in w2v
# word could<br not in w2v
# word alfonso not in w2v
# word dixon's not in w2v
# word "tom not in w2v
# word nastassja not in w2v
# word 'not not in w2v
# word macready not in w2v
# word barbet not in w2v
# word longer<br not in w2v
# word "classic" not in w2v
# word burstyn not in w2v
# word yawn<br not in w2v
# word hbo's not in w2v
# word zombie" not in w2v
# word kristy not in w2v
# word grace" not in w2v
# word this?<br not in w2v
# word morty not in w2v
# word karloff's not in w2v
# word flick! not in w2v
# word keyes not in w2v
# word varney not in w2v
# word too; not in w2v
# word urmila not in w2v
# word everyone! not in w2v
# word free<br not in w2v
# word nobody's not in w2v
# word forgotten<br not in w2v
# word who? not in w2v
# word humourless not in w2v
# word newhart not in w2v
# word ridgemont not in w2v
# word movieit's not in w2v
# word bettie's not in w2v
# word script's not in w2v
# word merkerson not in w2v
# word krista not in w2v
# word you!" not in w2v
# word caribe not in w2v
# word happygolucky not in w2v
# word mason's not in w2v
# word d&d not in w2v
# word movie?<br not in w2v
# word truth<br not in w2v
# word "hell not in w2v
# word "dan not in w2v
# word mcgowan not in w2v
# word />rent not in w2v
# word effects; not in w2v
# word "original" not in w2v
# word amelie not in w2v
# word i" not in w2v
# word />thus not in w2v
# word drew's not in w2v
# word work! not in w2v
# word lecter not in w2v
# word />would not in w2v
# word 'i'm not in w2v
# word ago! not in w2v
# word collection<br not in w2v
# word ophelia not in w2v
# word fabian not in w2v
# word convincing<br not in w2v
# word shots<br not in w2v
# word top<br not in w2v
# word adama not in w2v
# word "yes" not in w2v
# word forster not in w2v
# word other? not in w2v
# word hardy's not in w2v
# word spoilers*<br not in w2v
# word "hard not in w2v
# word steenburgen not in w2v
# word !!<br not in w2v
# word />we're not in w2v
# word fingersmith not in w2v
# word bbc's not in w2v
# word brinke not in w2v
# word "silence not in w2v
# word streep's not in w2v
# word "columbo" not in w2v
# word franco's not in w2v
# word iwerks not in w2v
# word alfre not in w2v
# word 'horror' not in w2v
# word burnett not in w2v
# word effective<br not in w2v
# word boll's not in w2v
# word with? not in w2v
# word 54 not in w2v
# word aidan not in w2v
# word 42nd not in w2v
# word "mother not in w2v
# word />can't not in w2v
# word island<br not in w2v
# word wonderful<br not in w2v
# word catandmouse not in w2v
# word lucy" not in w2v
# word world; not in w2v
# word aimee not in w2v
# word boy' not in w2v
# word berkley not in w2v
# word erasmus not in w2v
# word darlene not in w2v
# word "aliens" not in w2v
# word hitch's not in w2v
# word hood" not in w2v
# word "manos not in w2v
# word myself<br not in w2v
# word oswald not in w2v
# word "fun" not in w2v
# word set<br not in w2v
# word cambodian not in w2v
# word niro's not in w2v
# word claudette not in w2v
# word flick" not in w2v
# word kaufman's not in w2v
# word "watch not in w2v
# word centred not in w2v
# word in; not in w2v
# word edge" not in w2v
# word bed" not in w2v
# word 58 not in w2v
# word bob's not in w2v
# word />needless not in w2v
# word "modern not in w2v
# word there?" not in w2v
# word leila not in w2v
# word grieco not in w2v
# word yimou not in w2v
# word antonioni's not in w2v
# word mike's not in w2v
# word "getting not in w2v
# word entertainment! not in w2v
# word ggirl not in w2v
# word "play not in w2v
# word others" not in w2v
# word "no" not in w2v
# word "johnny not in w2v
# word picture's not in w2v
# word footage<br not in w2v
# word "left not in w2v
# word ivey not in w2v
# word desdemona not in w2v
# word rigg not in w2v
# word rampling not in w2v
# word shreck not in w2v
# word burman not in w2v
# word "moonstruck" not in w2v
# word preminger's not in w2v
# word abhay not in w2v
# word rvd not in w2v
# word please<br not in w2v
# word slausen not in w2v
# word guevara not in w2v
# word *spoiler* not in w2v
# word gino not in w2v
# word conrack not in w2v
# word "fear not in w2v
# word sopranos" not in w2v
# word behind<br not in w2v
# word though! not in w2v
# word revenge" not in w2v
# word rocks! not in w2v
# word $200 not in w2v
# word borat not in w2v
# word wife? not in w2v
# word thirdrate not in w2v
# word costs<br not in w2v
# word huston's not in w2v
# word irani not in w2v
# word 66 not in w2v
# word anywhere<br not in w2v
# word royston not in w2v
# word farmer's not in w2v
# word light" not in w2v
# word peet not in w2v
# word marykate not in w2v
# word kher not in w2v
# word labeouf not in w2v
# word more" not in w2v
# word sequence<br not in w2v
# word "queen not in w2v
# word premise<br not in w2v
# word cinema! not in w2v
# word ahead<br not in w2v
# word music; not in w2v
# word cowboy' not in w2v
# word hell's not in w2v
# word ernesto not in w2v
# word paxinou not in w2v
# word "romance" not in w2v
# word lover's not in w2v
# word baio not in w2v
# word />favorite not in w2v
# word romance<br not in w2v
# word annabelle not in w2v
# word />had not in w2v
# word well? not in w2v
# word sarah's not in w2v
# word fozzie not in w2v
# word chabrol not in w2v
# word anymore? not in w2v
# word 90210 not in w2v
# word selfimportant not in w2v
# word 81 not in w2v
# word beautiful! not in w2v
# word />starring not in w2v
# word />come not in w2v
# word white" not in w2v
# word cinderella's not in w2v
# word />among not in w2v
# word game? not in w2v
# word holmes' not in w2v
# word edmond not in w2v
# word cukor not in w2v
# word away' not in w2v
# word 5000 not in w2v
# word shining" not in w2v
# word "beautiful not in w2v
# word l&h not in w2v
# word "big" not in w2v
# word fastforwarding not in w2v
# word />admittedly not in w2v
# word mcnally not in w2v
# word sicilian not in w2v
# word />young not in w2v
# word phillipines not in w2v
# word impact" not in w2v
# word stateoftheart not in w2v
# word "rich not in w2v
# word />get not in w2v
# word something! not in w2v
# word aragorn not in w2v
# word watching! not in w2v
# word hiroshima not in w2v
# word o'neil not in w2v
# word moving<br not in w2v
# word />polarisdib not in w2v
# word feast" not in w2v
# word steve's not in w2v
# word eurotrash not in w2v
# word kalifornia not in w2v
# word audience? not in w2v
# word actor; not in w2v
# word together" not in w2v
# word garlin not in w2v
# word over" not in w2v
# word "run not in w2v
# word excop not in w2v
# word unger not in w2v
# word "maybe not in w2v
# word "ordinary not in w2v
# word mission<br not in w2v
# word face! not in w2v
# word treat<br not in w2v
# word thriller" not in w2v
# word florinda not in w2v
# word "children not in w2v
# word mortimer not in w2v
# word mononoke not in w2v
# word killer? not in w2v
# word "fame" not in w2v
# word "seven not in w2v
# word />frank not in w2v
# word believed<br not in w2v
# word oneliner not in w2v
# word science" not in w2v
# word helen's not in w2v
# word "thing" not in w2v
# word murray's not in w2v
# word love! not in w2v
# word bravo! not in w2v
# word star! not in w2v
# word roth's not in w2v
# word stan's not in w2v
# word 'comedy' not in w2v
# word old's not in w2v
# word marguerite not in w2v
# word "planet not in w2v
# word harbour not in w2v
# word dibiase not in w2v
# word />essentially not in w2v
# word />trust not in w2v
# word greenaway not in w2v
# word stephan not in w2v
# word believe<br not in w2v
# word marcy not in w2v
# word last<br not in w2v
# word 'it's not in w2v
# word daughterinlaw not in w2v
# word bening not in w2v
# word godard's not in w2v
# word loveinterest not in w2v
# word river" not in w2v
# word goes<br not in w2v
# word group's not in w2v
# word woman! not in w2v
# word expectations<br not in w2v
# word schindler's not in w2v
# word />danny not in w2v
# word $10000 not in w2v
# word cagney's not in w2v
# word away? not in w2v
# word zatoichi not in w2v
# word "robot not in w2v
# word corinne not in w2v
# word noonan not in w2v
# word page" not in w2v
# word kid<br not in w2v
# word fast<br not in w2v
# word esposito not in w2v
# word beckett not in w2v
# word pimlico not in w2v
# word purpose? not in w2v
# word friggin' not in w2v
# word />considering not in w2v
# word game' not in w2v
# word soapopera not in w2v
# word car! not in w2v
# word "based not in w2v
# word thing; not in w2v
# word halfdecent not in w2v
# word '90s not in w2v
# word one!<br not in w2v
# word question<br not in w2v
# word lol! not in w2v
# word gilliam's not in w2v
# word jones" not in w2v
# word existence<br not in w2v
# word foer not in w2v
# word estelle not in w2v
# word fastmoving not in w2v
# word lily's not in w2v
# word hudson's not in w2v
# word lot's not in w2v
# word "wild not in w2v
# word keeley not in w2v
# word happy<br not in w2v
# word midian not in w2v
# word "seed" not in w2v
# word ;<br not in w2v
# word aweinspiring not in w2v
# word emotion<br not in w2v
# word "more not in w2v
# word reviews<br not in w2v
# word vogel not in w2v
# word filmmaking<br not in w2v
# word diane's not in w2v
# word fawcett not in w2v
# word oh! not in w2v
# word valeria not in w2v
# word carrere not in w2v
# word wrong; not in w2v
# word domergue not in w2v
# word akshaye not in w2v
# word being<br not in w2v
# word "day not in w2v
# word cleo not in w2v
# word "ah not in w2v
# word "road not in w2v
# word helga not in w2v
# word out' not in w2v
# word nest" not in w2v
# word xrated not in w2v
# word fact<br not in w2v
# word hamilton's not in w2v
# word urich not in w2v
# word "head" not in w2v
# word deathstalker not in w2v
# word />charlie not in w2v
# word train<br not in w2v
# word bigelow not in w2v
# word fellowes not in w2v
# word drummond not in w2v
# word dianne not in w2v
# word did? not in w2v
# word specialeffects not in w2v
# word everywhere<br not in w2v
# word second<br not in w2v
# word milos not in w2v
# word amadeus not in w2v
# word beethoven's not in w2v
# word family? not in w2v

# %%
#dump to pkl
with open('em_w2v_train.pkl', 'wb') as handle:
    pkl.dump(embedding_matrix, handle)

# %%
# load if saevd
with open('em_w2v_train.pkl', 'rb') as handle:
    embedding_matrix=pkl.load(handle)

# %%
from keras.layers import Embedding
embedding_layer = Embedding(vocabulary_size,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            trainable=False)  #-------unsure

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.08007812,  0.10498047,  0.04980469, ...,  0.00366211,
#          0.04760742, -0.06884766],
#        [-0.91204109,  0.88575532,  0.0025902 , ..., -0.50070606,
#         -0.4411896 , -0.5499527 ],
#        ...,
#        [ 0.08837891,  0.10644531,  0.09912109, ..., -0.15820312,
#         -0.04760742, -0.07226562],
#        [ 0.01281738,  0.0078125 , -0.02758789, ..., -0.11328125,
#          0.05151367,  0.15820312],
#        [ 0.01275635, -0.12988281, -0.10058594, ..., -0.01928711,
#         -0.18261719,  0.12695312]])

# %%
embedding_matrix.shape
# Out:
# (20000, 300)

# %% [markdown]
# # normal embedding

# %%
from keras.layers import Embedding
EMBEDDING_DIM=300
vocabulary_size=min(len(word_index)+1,NUM_WORDS)

embedding_layer = Embedding(vocabulary_size,
                            EMBEDDING_DIM,trainable=False)

# %% [markdown]
# # model

# %%
from keras.layers import Dense, Input, GlobalMaxPooling1D
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.models import Model
from keras.layers import Input, Dense, Embedding, Conv2D, MaxPooling2D, Dropout,concatenate
from keras.layers.core import Reshape, Flatten
from keras.callbacks import EarlyStopping
from keras.models import Model
from keras import regularizers

# %%
def Conv1():
  sequence_length = X_train.shape[1]
  filter_sizes = [3,4,5]
  num_filters = 100
  drop = 0.5
  num_classes=2

  inputs = Input(shape=(sequence_length,))
  embedding = embedding_layer(inputs)
  reshape = Reshape((sequence_length,EMBEDDING_DIM,1))(embedding)

  conv_0 = Conv2D(num_filters, (filter_sizes[0], EMBEDDING_DIM),activation='relu',kernel_regularizer=regularizers.l2(0.01))(reshape)
  conv_1 = Conv2D(num_filters, (filter_sizes[1], EMBEDDING_DIM),activation='relu',kernel_regularizer=regularizers.l2(0.01))(reshape)
  conv_2 = Conv2D(num_filters, (filter_sizes[2], EMBEDDING_DIM),activation='relu',kernel_regularizer=regularizers.l2(0.01))(reshape)

  maxpool_0 = MaxPooling2D((sequence_length - filter_sizes[0] + 1, 1), strides=(1,1))(conv_0)
  maxpool_1 = MaxPooling2D((sequence_length - filter_sizes[1] + 1, 1), strides=(1,1))(conv_1)
  maxpool_2 = MaxPooling2D((sequence_length - filter_sizes[2] + 1, 1), strides=(1,1))(conv_2)

  merged_tensor = concatenate([maxpool_0, maxpool_1, maxpool_2], axis=1)
  flatten = Flatten()(merged_tensor)
  reshape = Reshape((3*num_filters,))(flatten)
  dropout = Dropout(drop)(flatten)
  output = Dense(units=num_classes, activation='softmax',kernel_regularizer=regularizers.l2(0.01))(dropout)

  # this creates a model that includes
  model = Model(inputs, output)

  return model

model=Conv1()

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 2172)]       0           []
#
#  embedding_1 (Embedding)        (None, 2172, 300)    6000000     ['input_3[0][0]']
#
#  reshape_4 (Reshape)            (None, 2172, 300, 1  0           ['embedding_1[1][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 2170, 1, 100  90100       ['reshape_4[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 2169, 1, 100  120100      ['reshape_4[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 2168, 1, 100  150100      ['reshape_4[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 1, 1, 100)   0           ['conv2d_6[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 1, 1, 100)   0           ['conv2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 1, 1, 100)   0           ['conv2d_8[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 3, 1, 100)    0           ['max_pooling2d_6[0][0]',
#                                                                   'max_pooling2d_7[0][0]',
#                                                                   'max_pooling2d_8[0][0]']
#
#  flatten_2 (Flatten)            (None, 300)          0           ['concatenate_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 300)          0           ['flatten_2[0][0]']
#
#  dense_2 (Dense)                (None, 2)            602         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 6,360,902
# Trainable params: 360,902
# Non-trainable params: 6,000,000
# __________________________________________________________________________________________________

# %% [markdown]
# # run model

# %%
from datetime import datetime

# %%
# Custom Class to print specified parameters during training
class PrintingCallback(tf.keras.callbacks.Callback):
    
    def on_epoch_end(self, epoch, logs=None):
        # print(logs.keys())
        print(
            "The average loss for epoch {} is {:7.2f} "
            "and accuracy is {:7.2f}.".format(
                epoch, logs["val_loss"], logs["val_accuracy"]
            ))
        lr = tf.keras.backend.get_value(self.model.optimizer.learning_rate)
        print("LR is:", lr)
    

# defining a function to checkpoint the model 

checkpoint_filepath = './normal_cnn/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose = True)

# %% [markdown]
# optimizer = Adam()
# model.compile(loss='categorical_crossentropy', optimizer=optimizer,
#               metrics=['accuracy'])
# print(model.summary())
# history = model.fit(X_train, y_train,
#           batch_size=256,
#           validation_data=(X_val, y_val),
#           epochs=2)
# print(history.history.keys())

# %%
adam = Adam(lr=1e-3)

model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])
#callbacks = [EarlyStopping(monitor='val_loss')]

start = datetime.now()

history = model.fit(X_train, y_train, batch_size=256, epochs=10, verbose=1, validation_data=(X_val, y_val),
         callbacks=[PrintingCallback(), model_checkpoint_callback])  # starts training

end = datetime.now()

print('time: ',end-start)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 137/137 [==============================] - ETA: 0s - loss: 0.7071 - accuracy: 0.6393The average loss for epoch 0 is    0.69 and accuracy is    0.67.
# LR is: 0.001
#
# Epoch 1: val_accuracy improved from -inf to 0.66609, saving model to ./normal_cnn/checkpoint
# 137/137 [==============================] - 73s 523ms/step - loss: 0.7071 - accuracy: 0.6393 - val_loss: 0.6907 - val_accuracy: 0.6661
# Epoch 2/10
# 137/137 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.6686The average loss for epoch 1 is    0.69 and accuracy is    0.68.
# LR is: 0.001
#
# Epoch 2: val_accuracy improved from 0.66609 to 0.67529, saving model to ./normal_cnn/checkpoint
# 137/137 [==============================] - 71s 517ms/step - loss: 0.6903 - accuracy: 0.6686 - val_loss: 0.6871 - val_accuracy: 0.6753
# Epoch 3/10
# 137/137 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.6731The average loss for epoch 2 is    0.69 and accuracy is    0.68.
# LR is: 0.001
#
# Epoch 3: val_accuracy improved from 0.67529 to 0.67876, saving model to ./normal_cnn/checkpoint
# 137/137 [==============================] - 71s 516ms/step - loss: 0.6892 - accuracy: 0.6731 - val_loss: 0.6868 - val_accuracy: 0.6788
# Epoch 4/10
# 137/137 [==============================] - ETA: 0s - loss: 0.6885 - accuracy: 0.6711The average loss for epoch 3 is    0.69 and accuracy is    0.68.
# LR is: 0.001
#
# Epoch 4: val_accuracy improved from 0.67876 to 0.68476, saving model to ./normal_cnn/checkpoint
# 137/137 [==============================] - 71s 517ms/step - loss: 0.6885 - accuracy: 0.6711 - val_loss: 0.6858 - val_accuracy: 0.6848
# Epoch 5/10
# 137/137 [==============================] - ETA: 0s - loss: 0.6873 - accuracy: 0.6736The average loss for epoch 4 is    0.69 and accuracy is    0.68.
# LR is: 0.001
#
# Epoch 5: val_accuracy did not improve from 0.68476
# 137/137 [==============================] - 70s 515ms/step - loss: 0.6873 - accuracy: 0.6736 - val_loss: 0.6851 - val_accuracy: 0.6794
# Epoch 6/10
# 137/137 [==============================] - ETA: 0s - loss: 0.6875 - accuracy: 0.6735The average loss for epoch 5 is    0.69 and accuracy is    0.68.
# LR is: 0.001
#
# Epoch 6: val_accuracy did not improve from 0.68476
# 137/137 [==============================] - 71s 516ms/step - loss: 0.6875 - accuracy: 0.6735 - val_loss: 0.6851 - val_accuracy: 0.6804
# Epoch 7/10
# 137/137 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.6749The average loss for epoch 6 is    0.69 and accuracy is    0.68.
# LR is: 0.001
#
# Epoch 7: val_accuracy did not improve from 0.68476
# 137/137 [==============================] - 71s 517ms/step - loss: 0.6870 - accuracy: 0.6749 - val_loss: 0.6851 - val_accuracy: 0.6768
# Epoch 8/10
# 137/137 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.6743The average loss for epoch 7 is    0.69 and accuracy is    0.68.
# LR is: 0.001
#
# Epoch 8: val_accuracy did not improve from 0.68476
# 137/137 [==============================] - 70s 515ms/step - loss: 0.6870 - accuracy: 0.6743 - val_loss: 0.6850 - val_accuracy: 0.6796
# Epoch 9/10
# 137/137 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.6738The average loss for epoch 8 is    0.68 and accuracy is    0.68.
# LR is: 0.001
#
# Epoch 9: val_accuracy did not improve from 0.68476
# 137/137 [==============================] - 71s 516ms/step - loss: 0.6869 - accuracy: 0.6738 - val_loss: 0.6845 - val_accuracy: 0.6840
# Epoch 10/10
# 137/137 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.6759The average loss for epoch 9 is    0.68 and accuracy is    0.68.
# LR is: 0.001
#
# Epoch 10: val_accuracy did not improve from 0.68476
# 137/137 [==============================] - 71s 517ms/step - loss: 0.6865 - accuracy: 0.6759 - val_loss: 0.6846 - val_accuracy: 0.6788
# time:  0:11:48.754362

# %%
#load from chkpt and continueto train
model.load_weights(checkpoint_filepath)

adam = Adam(lr=1e-3)

model.compile(loss='binary_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

start = datetime.now()

history = model.fit(X_train, y_train, batch_size=256, epochs=5, verbose=1, validation_data=(X_val, y_val),
         callbacks=[PrintingCallback(), model_checkpoint_callback])  # starts training

end = datetime.now()

print('time: ',end-start)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 137/137 [==============================] - ETA: 0s - loss: 0.6320 - accuracy: 0.7673The average loss for epoch 0 is    0.61 and accuracy is    0.80.
# LR is: 0.001
#
# Epoch 1: val_accuracy did not improve from 0.80411
# 137/137 [==============================] - 69s 494ms/step - loss: 0.6320 - accuracy: 0.7673 - val_loss: 0.6130 - val_accuracy: 0.8022
# Epoch 2/5
# 137/137 [==============================] - ETA: 0s - loss: 0.6247 - accuracy: 0.7719The average loss for epoch 1 is    0.61 and accuracy is    0.79.
# LR is: 0.001
#
# Epoch 2: val_accuracy did not improve from 0.80411
# 137/137 [==============================] - 69s 506ms/step - loss: 0.6247 - accuracy: 0.7719 - val_loss: 0.6131 - val_accuracy: 0.7917
# Epoch 3/5
# 137/137 [==============================] - ETA: 0s - loss: 0.6239 - accuracy: 0.7701The average loss for epoch 2 is    0.62 and accuracy is    0.80.
# LR is: 0.001
#
# Epoch 3: val_accuracy did not improve from 0.80411
# 137/137 [==============================] - 70s 511ms/step - loss: 0.6239 - accuracy: 0.7701 - val_loss: 0.6151 - val_accuracy: 0.7969
# Epoch 4/5
# 137/137 [==============================] - ETA: 0s - loss: 0.6270 - accuracy: 0.7685The average loss for epoch 3 is    0.62 and accuracy is    0.80.
# LR is: 0.001
#
# Epoch 4: val_accuracy did not improve from 0.80411
# 137/137 [==============================] - 70s 513ms/step - loss: 0.6270 - accuracy: 0.7685 - val_loss: 0.6157 - val_accuracy: 0.8006
# Epoch 5/5
# 137/137 [==============================] - ETA: 0s - loss: 0.6247 - accuracy: 0.7708The average loss for epoch 4 is    0.61 and accuracy is    0.80.
# LR is: 0.001
#
# Epoch 5: val_accuracy did not improve from 0.80411
# 137/137 [==============================] - 70s 513ms/step - loss: 0.6247 - accuracy: 0.7708 - val_loss: 0.6147 - val_accuracy: 0.7960
# time:  0:05:48.932244

# %%
import matplotlib.pyplot as plt

# %%
num_epoch=10

# %%
f, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(range(num_epoch), history.history['loss'], 'tab:blue', label="train loss")
ax1.plot(range(num_epoch), history.history['val_loss'], 'tab:red', label="val loss")

ax2.plot(range(num_epoch), history.history['accuracy'], 'tab:orange', label="train acc")
ax2.plot(range(num_epoch), history.history['val_accuracy'], 'tab:green', label="val acc")

ax1.legend()
ax2.legend()

# %%
#load from chkpt and continueto train
model.load_weights(checkpoint_filepath)

adam = Adam(lr=1e-3)

model.compile(loss='binary_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

start = datetime.now()

history2 = model.fit(X_train, y_train, batch_size=256, epochs=5, verbose=1, validation_data=(X_val, y_val),
         callbacks=[PrintingCallback(), model_checkpoint_callback])  # starts training

end = datetime.now()

print('time: ',end-start)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 137/137 [==============================] - ETA: 0s - loss: 0.6975 - accuracy: 0.6229The average loss for epoch 0 is    0.69 and accuracy is    0.61.
# LR is: 0.001
#
# Epoch 1: val_accuracy did not improve from 0.68476
# 137/137 [==============================] - 68s 479ms/step - loss: 0.6975 - accuracy: 0.6229 - val_loss: 0.6942 - val_accuracy: 0.6099
# Epoch 2/5
# 137/137 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.5882The average loss for epoch 1 is    0.69 and accuracy is    0.61.
# LR is: 0.001
#
# Epoch 2: val_accuracy did not improve from 0.68476
# 137/137 [==============================] - 68s 495ms/step - loss: 0.6938 - accuracy: 0.5882 - val_loss: 0.6935 - val_accuracy: 0.6069
# Epoch 3/5
# 137/137 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5232The average loss for epoch 2 is    0.69 and accuracy is    0.49.
# LR is: 0.001
#
# Epoch 3: val_accuracy did not improve from 0.68476
# 137/137 [==============================] - 69s 506ms/step - loss: 0.6934 - accuracy: 0.5232 - val_loss: 0.6934 - val_accuracy: 0.4874
# Epoch 4/5
# 137/137 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5047The average loss for epoch 3 is    0.69 and accuracy is    0.49.
# LR is: 0.001
#
# Epoch 4: val_accuracy did not improve from 0.68476
# 137/137 [==============================] - 70s 512ms/step - loss: 0.6932 - accuracy: 0.5047 - val_loss: 0.6933 - val_accuracy: 0.4874
# Epoch 5/5
#  10/137 [=>............................] - ETA: 59s - loss: 0.6931 - accuracy: 0.5102
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-b96f9cfb8a39> in <module>()
#      11
#      12 history2 = model.fit(X_train, y_train, batch_size=256, epochs=5, verbose=1, validation_data=(X_val, y_val),
# ---> 13          callbacks=[PrintingCallback(), model_checkpoint_callback])  # starts training
#      14
#      15 end = datetime.now()
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

# %%
num_epoch=30

# %%
f, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(range(num_epoch), history.history['loss'], 'tab:blue', label="train loss")
ax1.plot(range(num_epoch), history.history['val_loss'], 'tab:red', label="val loss")

ax2.plot(range(num_epoch), history.history['accuracy'], 'tab:orange', label="train acc")
ax2.plot(range(num_epoch), history.history['val_accuracy'], 'tab:green', label="val acc")

ax1.legend()
ax2.legend()

# %% [markdown]
# # test

# %%
start = datetime.now()
score, acc = model.evaluate(X_test, y_test, verbose=0)
end = datetime.now()
print('Test loss:', score)
print('Test accuracy:', acc)
print('time: ',end-start)
# Out:
# Test loss: 0.69319087266922
# Test accuracy: 0.5011335015296936
# time:  0:00:15.371933

# %%
model.load_weights(checkpoint_filepath)
start = datetime.now()
score, acc = model.evaluate(X_test, y_test, verbose=0)
end = datetime.now()
print('Test loss:', score)
print('Test accuracy:', acc)
print('time: ',end-start)
# Out:
# Test loss: 0.7066712975502014
# Test accuracy: 0.697559654712677
# time:  0:00:14.946519
